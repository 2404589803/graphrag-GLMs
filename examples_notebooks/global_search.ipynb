# %%
# Copyright (c) 2024 Microsoft Corporation.
# Licensed under the MIT License.

# %%
! pip install graphrag
# Out:
# Collecting graphrag
#   Downloading graphrag-0.1.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting aiofiles<25.0.0,>=24.1.0 (from graphrag)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting aiolimiter<2.0.0,>=1.1.0 (from graphrag)
#   Downloading aiolimiter-1.1.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting azure-identity<2.0.0,>=1.17.1 (from graphrag)
#   Downloading azure_identity-1.17.1-py3-none-any.whl.metadata (79 kB)
#      ---------------------------------------- 0.0/79.4 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/79.4 kB ? eta -:--:--
#      -------------- ----------------------- 30.7/79.4 kB 259.2 kB/s eta 0:00:01
#      -------------- ----------------------- 30.7/79.4 kB 259.2 kB/s eta 0:00:01
#      -------------- ----------------------- 30.7/79.4 kB 259.2 kB/s eta 0:00:01
#      -------------------------------------- 79.4/79.4 kB 339.2 kB/s eta 0:00:00
# Collecting azure-search-documents<12.0.0,>=11.4.0 (from graphrag)
#   Downloading azure_search_documents-11.4.0-py3-none-any.whl.metadata (22 kB)
# Collecting azure-storage-blob<13.0.0,>=12.19.0 (from graphrag)
#   Downloading azure_storage_blob-12.20.0-py3-none-any.whl.metadata (26 kB)
# Collecting datashaper<0.0.50,>=0.0.49 (from graphrag)
#   Downloading datashaper-0.0.49-py3-none-any.whl.metadata (3.7 kB)
# Collecting devtools<0.13.0,>=0.12.2 (from graphrag)
#   Downloading devtools-0.12.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting environs<12.0.0,>=11.0.0 (from graphrag)
#   Downloading environs-11.0.0-py3-none-any.whl.metadata (13 kB)
# Collecting fastparquet<2025.0.0,>=2024.2.0 (from graphrag)
#   Downloading fastparquet-2024.5.0-cp311-cp311-win_amd64.whl.metadata (4.3 kB)
# Collecting graspologic<4.0.0,>=3.4.1 (from graphrag)
#   Downloading graspologic-3.4.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting lancedb<0.10.0,>=0.9.0 (from graphrag)
#   Downloading lancedb-0.9.0-cp38-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from graphrag) (1.6.0)
# Requirement already satisfied: networkx<4,>=3 in c:\programdata\anaconda3\lib\site-packages (from graphrag) (3.1)
# Requirement already satisfied: nltk==3.8.1 in c:\programdata\anaconda3\lib\site-packages (from graphrag) (3.8.1)
# Collecting numba==0.60.0 (from graphrag)
#   Downloading numba-0.60.0-cp311-cp311-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.25.2 in c:\programdata\anaconda3\lib\site-packages (from graphrag) (1.26.4)
# Collecting openai<2.0.0,>=1.35.7 (from graphrag)
#   Downloading openai-1.35.10-py3-none-any.whl.metadata (21 kB)
# Collecting pyaml-env<2.0.0,>=1.2.1 (from graphrag)
#   Downloading pyaml_env-1.2.1-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic<3,>=2 (from graphrag)
#   Downloading pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
#      ---------------------------------------- 0.0/125.2 kB ? eta -:--:--
#      --------- ----------------------------- 30.7/125.2 kB 1.4 MB/s eta 0:00:01
#      ------------------ ------------------ 61.4/125.2 kB 825.8 kB/s eta 0:00:01
#      ------------------ ------------------ 61.4/125.2 kB 825.8 kB/s eta 0:00:01
#      ------------------ ------------------ 61.4/125.2 kB 825.8 kB/s eta 0:00:01
#      ------------------------------------ 125.2/125.2 kB 614.7 kB/s eta 0:00:00
# Collecting python-dotenv<2.0.0,>=1.0.0 (from graphrag)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.1 in c:\programdata\anaconda3\lib\site-packages (from graphrag) (6.0.1)
# Collecting rich<14.0.0,>=13.6.0 (from graphrag)
#   Downloading rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting scipy==1.12.0 (from graphrag)
#   Downloading scipy-1.12.0-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ---------------------------------------- 60.4/60.4 kB 3.1 MB/s eta 0:00:00
# Collecting swifter<2.0.0,>=1.4.0 (from graphrag)
#   Downloading swifter-1.4.0.tar.gz (1.2 MB)
#      ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#      -- ------------------------------------- 0.1/1.2 MB ? eta -:--:--
#      ---- ----------------------------------- 0.1/1.2 MB 2.4 MB/s eta 0:00:01
#      ------- -------------------------------- 0.2/1.2 MB 2.8 MB/s eta 0:00:01
#      ----------- ---------------------------- 0.3/1.2 MB 2.3 MB/s eta 0:00:01
#      ------------- -------------------------- 0.4/1.2 MB 2.1 MB/s eta 0:00:01
#      ---------------- ----------------------- 0.5/1.2 MB 2.1 MB/s eta 0:00:01
#      -------------------- ------------------- 0.6/1.2 MB 2.1 MB/s eta 0:00:01
#      ---------------------- ----------------- 0.7/1.2 MB 2.0 MB/s eta 0:00:01
#      ---------------------------- ----------- 0.8/1.2 MB 2.2 MB/s eta 0:00:01
#      ------------------------------- -------- 0.9/1.2 MB 2.2 MB/s eta 0:00:01
#      ----------------------------------- ---- 1.1/1.2 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------------- 1.2/1.2 MB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting tenacity<9.0.0,>=8.2.3 (from graphrag)
#   Downloading tenacity-8.4.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting textual<0.71.0,>=0.70.0 (from graphrag)
#   Downloading textual-0.70.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: tiktoken<0.8.0,>=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from graphrag) (0.7.0)
# Collecting typing-extensions<5.0.0,>=4.12.2 (from graphrag)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk==3.8.1->graphrag) (8.1.7)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from nltk==3.8.1->graphrag) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\lib\site-packages (from nltk==3.8.1->graphrag) (2023.10.3)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from nltk==3.8.1->graphrag) (4.65.0)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba==0.60.0->graphrag)
#   Downloading llvmlite-0.43.0-cp311-cp311-win_amd64.whl.metadata (4.9 kB)
# Collecting azure-core>=1.23.0 (from azure-identity<2.0.0,>=1.17.1->graphrag)
#   Downloading azure_core-1.30.2-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: cryptography>=2.5 in c:\programdata\anaconda3\lib\site-packages (from azure-identity<2.0.0,>=1.17.1->graphrag) (42.0.2)
# Collecting msal>=1.24.0 (from azure-identity<2.0.0,>=1.17.1->graphrag)
#   Downloading msal-1.29.0-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=0.3.0 (from azure-identity<2.0.0,>=1.17.1->graphrag)
#   Downloading msal_extensions-1.2.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting azure-common~=1.1 (from azure-search-documents<12.0.0,>=11.4.0->graphrag)
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting isodate>=0.6.0 (from azure-search-documents<12.0.0,>=11.4.0->graphrag)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Collecting diskcache<6.0.0,>=5.6.3 (from datashaper<0.0.50,>=0.0.49->graphrag)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Collecting jsonschema<5.0.0,>=4.21.1 (from datashaper<0.0.50,>=0.0.49->graphrag)
#   Downloading jsonschema-4.22.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting pandas<3.0.0,>=2.2.0 (from datashaper<0.0.50,>=0.0.49->graphrag)
#   Downloading pandas-2.2.2-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting pyarrow<16.0.0,>=15.0.0 (from datashaper<0.0.50,>=0.0.49->graphrag)
#   Downloading pyarrow-15.0.2-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: asttokens<3.0.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from devtools<0.13.0,>=0.12.2->graphrag) (2.0.5)
# Collecting executing>=1.1.1 (from devtools<0.13.0,>=0.12.2->graphrag)
#   Downloading executing-2.0.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: pygments>=2.15.0 in c:\programdata\anaconda3\lib\site-packages (from devtools<0.13.0,>=0.12.2->graphrag) (2.15.1)
# Requirement already satisfied: marshmallow>=3.13.0 in c:\programdata\anaconda3\lib\site-packages (from environs<12.0.0,>=11.0.0->graphrag) (3.21.3)
# Collecting cramjam>=2.3 (from fastparquet<2025.0.0,>=2024.2.0->graphrag)
#   Downloading cramjam-2.8.3-cp311-none-win_amd64.whl.metadata (4.3 kB)
# Requirement already satisfied: fsspec in c:\programdata\anaconda3\lib\site-packages (from fastparquet<2025.0.0,>=2024.2.0->graphrag) (2023.10.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from fastparquet<2025.0.0,>=2024.2.0->graphrag) (24.1)
# Collecting POT<0.10,>=0.9 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading POT-0.9.4-cp311-cp311-win_amd64.whl.metadata (33 kB)
# Collecting anytree<3.0.0,>=2.12.1 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading anytree-2.12.1-py3-none-any.whl.metadata (8.1 kB)
# Collecting beartype<0.19.0,>=0.18.5 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading beartype-0.18.5-py3-none-any.whl.metadata (30 kB)
# Collecting gensim<5.0.0,>=4.3.2 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading gensim-4.3.2-cp311-cp311-win_amd64.whl.metadata (8.5 kB)
# Collecting graspologic-native<2.0.0,>=1.2.1 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading graspologic_native-1.2.1-cp36-abi3-win_amd64.whl.metadata (2.0 kB)
# Collecting hyppo<0.5.0,>=0.4.0 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading hyppo-0.4.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting joblib (from nltk==3.8.1->graphrag)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting matplotlib<4.0.0,>=3.8.4 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading matplotlib-3.9.1-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting scikit-learn<2.0.0,>=1.4.2 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading scikit_learn-1.5.1-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Collecting seaborn<0.14.0,>=0.13.2 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting statsmodels<0.15.0,>=0.14.2 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading statsmodels-0.14.2-cp311-cp311-win_amd64.whl.metadata (9.5 kB)
# Collecting umap-learn<0.6.0,>=0.5.6 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading umap_learn-0.5.6-py3-none-any.whl.metadata (21 kB)
# Collecting deprecation (from lancedb<0.10.0,>=0.9.0->graphrag)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting pylance==0.13.0 (from lancedb<0.10.0,>=0.9.0->graphrag)
#   Downloading pylance-0.13.0-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Collecting ratelimiter~=1.0 (from lancedb<0.10.0,>=0.9.0->graphrag)
#   Downloading ratelimiter-1.2.0.post0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: requests>=2.31.0 in c:\programdata\anaconda3\lib\site-packages (from lancedb<0.10.0,>=0.9.0->graphrag) (2.31.0)
# Collecting retry>=0.9.2 (from lancedb<0.10.0,>=0.9.0->graphrag)
#   Downloading retry-0.9.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: attrs>=21.3.0 in c:\programdata\anaconda3\lib\site-packages (from lancedb<0.10.0,>=0.9.0->graphrag) (23.1.0)
# Requirement already satisfied: cachetools in c:\programdata\anaconda3\lib\site-packages (from lancedb<0.10.0,>=0.9.0->graphrag) (4.2.2)
# Requirement already satisfied: overrides>=0.7 in c:\programdata\anaconda3\lib\site-packages (from lancedb<0.10.0,>=0.9.0->graphrag) (7.4.0)
# Collecting pyarrow<16.0.0,>=15.0.0 (from datashaper<0.0.50,>=0.0.49->graphrag)
#   Downloading pyarrow-15.0.0-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\programdata\anaconda3\lib\site-packages (from openai<2.0.0,>=1.35.7->graphrag) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\programdata\anaconda3\lib\site-packages (from openai<2.0.0,>=1.35.7->graphrag) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from openai<2.0.0,>=1.35.7->graphrag) (0.27.0)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from openai<2.0.0,>=1.35.7->graphrag) (1.3.0)
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=2->graphrag)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.20.1 (from pydantic<3,>=2->graphrag)
#   Downloading pydantic_core-2.20.1-cp311-none-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\programdata\anaconda3\lib\site-packages (from rich<14.0.0,>=13.6.0->graphrag) (2.2.0)
# Requirement already satisfied: psutil>=5.6.6 in c:\programdata\anaconda3\lib\site-packages (from swifter<2.0.0,>=1.4.0->graphrag) (5.9.0)
# Requirement already satisfied: dask>=2.10.0 in c:\programdata\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter<2.0.0,>=1.4.0->graphrag) (2023.11.0)
# Requirement already satisfied: idna>=2.8 in c:\programdata\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.35.7->graphrag) (3.4)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from anytree<3.0.0,>=2.12.1->graspologic<4.0.0,>=3.4.1->graphrag) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in c:\programdata\anaconda3\lib\site-packages (from cryptography>=2.5->azure-identity<2.0.0,>=1.17.1->graphrag) (1.16.0)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\programdata\anaconda3\lib\site-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter<2.0.0,>=1.4.0->graphrag) (2.2.1)
# Requirement already satisfied: partd>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter<2.0.0,>=1.4.0->graphrag) (1.4.1)
# Requirement already satisfied: toolz>=0.10.0 in c:\programdata\anaconda3\lib\site-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter<2.0.0,>=1.4.0->graphrag) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\programdata\anaconda3\lib\site-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter<2.0.0,>=1.4.0->graphrag) (7.0.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click->nltk==3.8.1->graphrag) (0.4.6)
# Requirement already satisfied: smart-open>=1.8.1 in c:\programdata\anaconda3\lib\site-packages (from gensim<5.0.0,>=4.3.2->graspologic<4.0.0,>=3.4.1->graphrag) (5.2.1)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.35.7->graphrag) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.35.7->graphrag) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.35.7->graphrag) (0.14.0)
# Collecting autograd>=1.3 (from hyppo<0.5.0,>=0.4.0->graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading autograd-1.6.2-py3-none-any.whl.metadata (706 bytes)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\programdata\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.21.1->datashaper<0.0.50,>=0.0.49->graphrag) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\programdata\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.21.1->datashaper<0.0.50,>=0.0.49->graphrag) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\programdata\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.21.1->datashaper<0.0.50,>=0.0.49->graphrag) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\programdata\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.6.0->graphrag) (0.1.0)
# Requirement already satisfied: linkify-it-py<3,>=1 in c:\programdata\anaconda3\lib\site-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual<0.71.0,>=0.70.0->graphrag) (2.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\programdata\anaconda3\lib\site-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual<0.71.0,>=0.70.0->graphrag) (0.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.8.4->graspologic<4.0.0,>=3.4.1->graphrag) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.8.4->graspologic<4.0.0,>=3.4.1->graphrag) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.8.4->graspologic<4.0.0,>=3.4.1->graphrag) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.8.4->graspologic<4.0.0,>=3.4.1->graphrag) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.8.4->graspologic<4.0.0,>=3.4.1->graphrag) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.8.4->graspologic<4.0.0,>=3.4.1->graphrag) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.8.4->graspologic<4.0.0,>=3.4.1->graphrag) (2.8.2)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.24.0->azure-identity<2.0.0,>=1.17.1->graphrag) (2.4.0)
# Collecting portalocker<3,>=1.4 (from msal-extensions>=0.3.0->azure-identity<2.0.0,>=1.17.1->graphrag)
#   Downloading portalocker-2.10.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas<3.0.0,>=2.2.0->datashaper<0.0.50,>=0.0.49->graphrag) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas<3.0.0,>=2.2.0->datashaper<0.0.50,>=0.0.49->graphrag) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.31.0->lancedb<0.10.0,>=0.9.0->graphrag) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.31.0->lancedb<0.10.0,>=0.9.0->graphrag) (2.0.7)
# Requirement already satisfied: decorator>=3.4.2 in c:\programdata\anaconda3\lib\site-packages (from retry>=0.9.2->lancedb<0.10.0,>=0.9.0->graphrag) (5.1.1)
# Collecting py<2.0.0,>=1.4.26 (from retry>=0.9.2->lancedb<0.10.0,>=0.9.0->graphrag)
#   Downloading py-1.11.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn<2.0.0,>=1.4.2->graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting patsy>=0.5.6 (from statsmodels<0.15.0,>=0.14.2->graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting pynndescent>=0.5 (from umap-learn<0.6.0,>=0.5.6->graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: future>=0.15.2 in c:\programdata\anaconda3\lib\site-packages (from autograd>=1.3->hyppo<0.5.0,>=0.4.0->graspologic<4.0.0,>=3.4.1->graphrag) (0.18.3)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity<2.0.0,>=1.17.1->graphrag) (2.21)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=4.13.0->dask>=2.10.0->dask[dataframe]>=2.10.0->swifter<2.0.0,>=1.4.0->graphrag) (3.17.0)
# Requirement already satisfied: uc-micro-py in c:\programdata\anaconda3\lib\site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify,plugins]>=2.1.0->textual<0.71.0,>=0.70.0->graphrag) (1.0.1)
# Requirement already satisfied: locket in c:\programdata\anaconda3\lib\site-packages (from partd>=1.2.0->dask>=2.10.0->dask[dataframe]>=2.10.0->swifter<2.0.0,>=1.4.0->graphrag) (1.0.0)
# Requirement already satisfied: pywin32>=226 in c:\programdata\anaconda3\lib\site-packages (from portalocker<3,>=1.4->msal-extensions>=0.3.0->azure-identity<2.0.0,>=1.17.1->graphrag) (305.1)
# Downloading graphrag-0.1.1-py3-none-any.whl (361 kB)
#    ---------------------------------------- 0.0/361.1 kB ? eta -:--:--
#    ---------- ----------------------------- 92.2/361.1 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 361.1/361.1 kB 5.6 MB/s eta 0:00:00
# Downloading numba-0.60.0-cp311-cp311-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.7 MB 9.6 MB/s eta 0:00:01
#    -------- ------------------------------- 0.6/2.7 MB 6.3 MB/s eta 0:00:01
#    -------------- ------------------------- 1.0/2.7 MB 6.9 MB/s eta 0:00:01
#    ------------------ --------------------- 1.3/2.7 MB 7.3 MB/s eta 0:00:01
#    ------------------------ --------------- 1.6/2.7 MB 7.0 MB/s eta 0:00:01
#    ------------------------------ --------- 2.0/2.7 MB 7.6 MB/s eta 0:00:01
#    --------------------------------- ------ 2.3/2.7 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 7.1 MB/s eta 0:00:00
# Downloading scipy-1.12.0-cp311-cp311-win_amd64.whl (46.2 MB)
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    ---------------------------------------- 0.2/46.2 MB 6.9 MB/s eta 0:00:07
#    ---------------------------------------- 0.5/46.2 MB 6.6 MB/s eta 0:00:07
#     --------------------------------------- 0.7/46.2 MB 4.6 MB/s eta 0:00:10
#     --------------------------------------- 1.1/46.2 MB 5.6 MB/s eta 0:00:09
#    - -------------------------------------- 1.5/46.2 MB 6.4 MB/s eta 0:00:07
#    - -------------------------------------- 1.8/46.2 MB 6.5 MB/s eta 0:00:07
#    - -------------------------------------- 2.0/46.2 MB 6.2 MB/s eta 0:00:08
#    - -------------------------------------- 2.2/46.2 MB 5.8 MB/s eta 0:00:08
#    -- ------------------------------------- 2.6/46.2 MB 6.1 MB/s eta 0:00:08
#    -- ------------------------------------- 2.8/46.2 MB 6.0 MB/s eta 0:00:08
#    -- ------------------------------------- 3.2/46.2 MB 6.1 MB/s eta 0:00:08
#    -- ------------------------------------- 3.4/46.2 MB 6.0 MB/s eta 0:00:08
#    --- ------------------------------------ 3.7/46.2 MB 6.1 MB/s eta 0:00:07
#    --- ------------------------------------ 4.2/46.2 MB 6.4 MB/s eta 0:00:07
#    --- ------------------------------------ 4.6/46.2 MB 6.5 MB/s eta 0:00:07
#    ---- ----------------------------------- 4.9/46.2 MB 6.6 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.1/46.2 MB 6.5 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.4/46.2 MB 6.4 MB/s eta 0:00:07
#    ----- ---------------------------------- 5.9/46.2 MB 6.6 MB/s eta 0:00:07
#    ----- ---------------------------------- 6.2/46.2 MB 6.6 MB/s eta 0:00:07
#    ----- ---------------------------------- 6.5/46.2 MB 6.6 MB/s eta 0:00:07
#    ----- ---------------------------------- 6.9/46.2 MB 6.7 MB/s eta 0:00:06
#    ------ --------------------------------- 7.4/46.2 MB 6.9 MB/s eta 0:00:06
#    ------ --------------------------------- 7.4/46.2 MB 6.9 MB/s eta 0:00:06
#    ------ --------------------------------- 7.8/46.2 MB 6.7 MB/s eta 0:00:06
#    ------- -------------------------------- 8.1/46.2 MB 6.7 MB/s eta 0:00:06
#    ------- -------------------------------- 8.4/46.2 MB 6.8 MB/s eta 0:00:06
#    ------- -------------------------------- 8.8/46.2 MB 6.8 MB/s eta 0:00:06
#    -------- ------------------------------- 9.2/46.2 MB 6.9 MB/s eta 0:00:06
#    -------- ------------------------------- 9.6/46.2 MB 6.9 MB/s eta 0:00:06
#    -------- ------------------------------- 10.0/46.2 MB 6.9 MB/s eta 0:00:06
#    -------- ------------------------------- 10.3/46.2 MB 7.0 MB/s eta 0:00:06
#    --------- ------------------------------ 10.6/46.2 MB 7.0 MB/s eta 0:00:06
#    --------- ------------------------------ 10.8/46.2 MB 7.1 MB/s eta 0:00:05
#    --------- ------------------------------ 10.8/46.2 MB 7.1 MB/s eta 0:00:05
#    --------- ------------------------------ 11.1/46.2 MB 6.8 MB/s eta 0:00:06
#    --------- ------------------------------ 11.4/46.2 MB 6.7 MB/s eta 0:00:06
#    ---------- ----------------------------- 11.8/46.2 MB 6.7 MB/s eta 0:00:06
#    ---------- ----------------------------- 12.2/46.2 MB 6.9 MB/s eta 0:00:05
#    ---------- ----------------------------- 12.5/46.2 MB 7.0 MB/s eta 0:00:05
#    ----------- ---------------------------- 13.0/46.2 MB 7.0 MB/s eta 0:00:05
#    ----------- ---------------------------- 13.3/46.2 MB 7.0 MB/s eta 0:00:05
#    ----------- ---------------------------- 13.7/46.2 MB 7.1 MB/s eta 0:00:05
#    ------------ --------------------------- 14.2/46.2 MB 7.2 MB/s eta 0:00:05
#    ------------ --------------------------- 14.6/46.2 MB 7.2 MB/s eta 0:00:05
#    ------------ --------------------------- 15.0/46.2 MB 7.3 MB/s eta 0:00:05
#    ------------- -------------------------- 15.2/46.2 MB 7.2 MB/s eta 0:00:05
#    ------------- -------------------------- 15.6/46.2 MB 7.3 MB/s eta 0:00:05
#    ------------- -------------------------- 16.0/46.2 MB 7.3 MB/s eta 0:00:05
#    -------------- ------------------------- 16.4/46.2 MB 7.4 MB/s eta 0:00:05
#    -------------- ------------------------- 16.9/46.2 MB 7.4 MB/s eta 0:00:04
#    -------------- ------------------------- 17.2/46.2 MB 7.5 MB/s eta 0:00:04
#    --------------- ------------------------ 17.7/46.2 MB 7.7 MB/s eta 0:00:04
#    --------------- ------------------------ 18.1/46.2 MB 7.7 MB/s eta 0:00:04
#    ---------------- ----------------------- 18.6/46.2 MB 7.8 MB/s eta 0:00:04
#    ---------------- ----------------------- 19.0/46.2 MB 7.9 MB/s eta 0:00:04
#    ---------------- ----------------------- 19.3/46.2 MB 7.8 MB/s eta 0:00:04
#    ----------------- ---------------------- 19.9/46.2 MB 7.9 MB/s eta 0:00:04
#    ----------------- ---------------------- 20.3/46.2 MB 8.0 MB/s eta 0:00:04
#    ------------------ --------------------- 20.8/46.2 MB 8.2 MB/s eta 0:00:04
#    ------------------ --------------------- 21.2/46.2 MB 8.6 MB/s eta 0:00:03
#    ------------------ --------------------- 21.6/46.2 MB 8.7 MB/s eta 0:00:03
#    ------------------- -------------------- 22.1/46.2 MB 8.8 MB/s eta 0:00:03
#    ------------------- -------------------- 22.4/46.2 MB 8.8 MB/s eta 0:00:03
#    ------------------- -------------------- 22.9/46.2 MB 9.0 MB/s eta 0:00:03
#    -------------------- ------------------- 23.3/46.2 MB 9.0 MB/s eta 0:00:03
#    -------------------- ------------------- 23.8/46.2 MB 9.1 MB/s eta 0:00:03
#    --------------------- ------------------ 24.2/46.2 MB 9.1 MB/s eta 0:00:03
#    --------------------- ------------------ 24.6/46.2 MB 9.0 MB/s eta 0:00:03
#    --------------------- ------------------ 25.0/46.2 MB 9.0 MB/s eta 0:00:03
#    ---------------------- ----------------- 25.4/46.2 MB 9.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 25.7/46.2 MB 9.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 25.7/46.2 MB 9.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 26.0/46.2 MB 8.6 MB/s eta 0:00:03
#    ---------------------- ----------------- 26.4/46.2 MB 8.6 MB/s eta 0:00:03
#    ----------------------- ---------------- 26.8/46.2 MB 8.6 MB/s eta 0:00:03
#    ----------------------- ---------------- 27
2 MB 5.6 MB/s eta 0:00:01
#    ------------------------------------ --- 42.7/46.2 MB 5.6 MB/s eta 0:00:01
#    ------------------------------------- -- 42.9/46.2 MB 5.5 MB/s eta 0:00:01
#    ------------------------------------- -- 43.2/46.2 MB 5.4 MB/s eta 0:00:01
#    ------------------------------------- -- 43.5/46.2 MB 5.5 MB/s eta 0:00:01
#    ------------------------------------- -- 43.7/46.2 MB 5.5 MB/s eta 0:00:01
#    -------------------------------------- - 44.0/46.2 MB 5.5 MB/s eta 0:00:01
#    -------------------------------------- - 44.4/46.2 MB 5.5 MB/s eta 0:00:01
#    -------------------------------------- - 44.8/46.2 MB 5.5 MB/s eta 0:00:01
#    -------------------------------------- - 45.0/46.2 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  45.4/46.2 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------  45.7/46.2 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------  46.0/46.2 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 46.2/46.2 MB 5.4 MB/s eta 0:00:00
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading aiolimiter-1.1.0-py3-none-any.whl (7.2 kB)
# Downloading azure_identity-1.17.1-py3-none-any.whl (173 kB)
#    ---------------------------------------- 0.0/173.2 kB ? eta -:--:--
#    ---------------------------------------- 173.2/173.2 kB 3.5 MB/s eta 0:00:00
# Downloading azure_search_documents-11.4.0-py3-none-any.whl (283 kB)
#    ---------------------------------------- 0.0/283.8 kB ? eta -:--:--
#    ---------------------------------------- 283.8/283.8 kB 8.8 MB/s eta 0:00:00
# Downloading azure_storage_blob-12.20.0-py3-none-any.whl (392 kB)
#    ---------------------------------------- 0.0/392.2 kB ? eta -:--:--
#    ---------------------------------------  389.1/392.2 kB 8.1 MB/s eta 0:00:01
#    ---------------------------------------- 392.2/392.2 kB 6.1 MB/s eta 0:00:00
# Downloading datashaper-0.0.49-py3-none-any.whl (71 kB)
#    ---------------------------------------- 0.0/72.0 kB ? eta -:--:--
#    ---------------------------------------- 72.0/72.0 kB ? eta 0:00:00
# Downloading devtools-0.12.2-py3-none-any.whl (19 kB)
# Downloading environs-11.0.0-py3-none-any.whl (12 kB)
# Downloading fastparquet-2024.5.0-cp311-cp311-win_amd64.whl (671 kB)
#    ---------------------------------------- 0.0/672.0 kB ? eta -:--:--
#    ----------------------- ---------------- 399.4/672.0 kB 8.3 MB/s eta 0:00:01
#    -------------------------------------- - 645.1/672.0 kB 8.0 MB/s eta 0:00:01
#    ---------------------------------------- 672.0/672.0 kB 6.0 MB/s eta 0:00:00
# Downloading graspologic-3.4.1-py3-none-any.whl (5.2 MB)
#    ---------------------------------------- 0.0/5.2 MB ? eta -:--:--
#    - -------------------------------------- 0.2/5.2 MB 4.1 MB/s eta 0:00:02
#    --- ------------------------------------ 0.4/5.2 MB 4.6 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.6/5.2 MB 5.1 MB/s eta 0:00:01
#    ------ --------------------------------- 0.8/5.2 MB 4.4 MB/s eta 0:00:01
#    -------- ------------------------------- 1.2/5.2 MB 5.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.3/5.2 MB 5.2 MB/s eta 0:00:01
#    ------------- -------------------------- 1.7/5.2 MB 5.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.2/5.2 MB 6.0 MB/s eta 0:00:01
#    ------------------ --------------------- 2.4/5.2 MB 5.9 MB/s eta 0:00:01
#    ------------------ --------------------- 2.4/5.2 MB 5.9 MB/s eta 0:00:01
#    -------------------- ------------------- 2.7/5.2 MB 5.4 MB/s eta 0:00:01
#    ------------------------ --------------- 3.2/5.2 MB 5.8 MB/s eta 0:00:01
#    --------------------------- ------------ 3.6/5.2 MB 6.1 MB/s eta 0:00:01
#    ------------------------------- -------- 4.1/5.2 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 4
whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB 9.6 MB/s eta 0:00:01
#    - -------------------------------------- 0.4/9.9 MB 7.6 MB/s eta 0:00:02
#    -- ------------------------------------- 0.6/9.9 MB 4.8 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.0/9.9 MB 5.7 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.3/9.9 MB 5.9 MB/s eta 0:00:02
#    ------- -------------------------------- 1.7/9.9 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.2/9.9 MB 7.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.6/9.9 MB 7.1 MB/s eta 0:00:02
#    ------------ --------------------------- 3.0/9.9 MB 7.3 MB/s eta 0:00:01
#    ------------- -------------------------- 3.3/9.9 MB 7.4 MB/s eta 0:00:01
#    --------------- ------------------------ 3.7/9.9 MB 7.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.1/9.9 MB 7.5 MB/s eta 0:00:01
#    ------------------ --------------------- 4.7/9.9 MB 7.8 MB/s eta 0:00:01
#    -------------------- ------------------- 5.1/9.9 MB 7.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.6/9.9 MB 8.1 MB/s eta 0:00:01
#    ------------------------ --------------- 5.9/9.9 MB 8.1 MB/s eta 0:00:01
#    ------------------------- -------------- 6.4/9.9 MB 8.2 MB/s eta 0:00:01
#    --------------------------- ------------ 6.9/9.9 MB 8.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.3/9.9 MB 8.3 MB/s eta 0:00:01
#    ------------------------------- -------- 7.6/9.9 MB 8.3 MB/s eta 0:00:01
#    -------------------------------- ------- 8.0/9.9 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.5/9.9 MB 8.5 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.9 MB 8.4 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.9 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 8.4 MB/s eta 0:00:00
# Downloading umap_learn-0.5.6-py3-none-any.whl (85 kB)
#    ---------------------------------------- 0.0/85.7 kB ? eta -:--:--
#    ---------------------------------------- 85.7/85.7 kB 5.0 MB/s eta 0:00:00
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading autograd-1.6.2-py3-none-any.whl (49 kB)
#    ---------------------------------------- 0.0/49.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/49.3 kB ? eta -:--:--
#    ---------------------------------------- 49.3/49.3 kB ? eta 0:00:00
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#    ---------------------------------------- 0.0/233.9 kB ? eta -:--:--
#    ---------------------------------------- 233.9/233.9 kB 7.2 MB/s eta 0:00:00
# Downloading portalocker-2.10.0-py3-none-any.whl (18 kB)
# Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
#    ---------------------------------------- 0.0/98.7 kB ? eta -:--:--
#    ---------------------------------------- 98.7/98.7 kB ? eta 0:00:00
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/56.9 kB ? eta -:--:--
#    ---------------------------------------- 56.9/56.9 kB ? eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Building wheels for collected packages: swifter
#   Building wheel for swifter (setup.py): started
#   Building wheel for swifter (setup.py): finished with status 'done'
#   Created wheel for swifter: filename=swifter-1.4.0-py3-none-any.whl size=16513 sha256=bf8765a4a351588c52fb5b78a49ce778711e5e7fd127def53389adcb4570ff30
#   Stored in directory: c:\users\administrator\appdata\local\pip\cache\wheels\ef\7f\bd\9bed48f078f3ee1fa75e0b29b6e0335ce1cb03a38d3443b3a3
# Successfully built swifter
# Installing collected packages: ratelimiter, azure-common, typing-extensions, threadpoolctl, tenacity, scipy, python-dotenv, pyarrow, pyaml-env, py, portalocker, patsy, llvmlite, joblib, isodate, graspologic-native, executing, diskcache, deprecation, cramjam, beartype, autograd, anytree, annotated-types, aiolimiter, aiofiles, scikit-learn, rich, retry, pylance, pydantic-core, POT, pandas, numba, matplotlib, gensim, environs, devtools, azure-core, statsmodels, seaborn, pynndescent, pydantic, jsonschema, hyppo, fastparquet, azure-storage-blob, azure-search-documents, umap-learn, textual, openai, msal, lancedb, datashaper, swifter, msal-extensions, graspologic, azure-identity, graphrag
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.9.0
#     Uninstalling typing_extensions-4.9.0:
#       Successfully uninstalled typing_extensions-4.9.0
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 2.2.0
#     Uninstalling threadpoolctl-2.2.0:
#       Successfully uninstalled threadpoolctl-2.2.0
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.2.2
#     Uninstalling tenacity-8.2.2:
#       Successfully uninstalled tenacity-8.2.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Uninstalling scipy-1.11.4:
#       Successfully uninstalled scipy-1.11.4
#   Attempting uninstall: python-dotenv
#     Found existing installation: python-dotenv 0.21.0
#     Uninstalling python-dotenv-0.21.0:
#       Successfully uninstalled python-dotenv-0.21.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
#   Attempting uninstall: patsy
#     Found existing installation: patsy 0.5.3
#     Uninstalling patsy-0.5.3:
#       Successfully uninstalled patsy-0.5.3
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.42.0
#     Uninstalling llvmlite-0.42.0:
#       Successfully uninstalled llvmlite-0.42.0
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.2.0
#     Uninstalling joblib-1.2.0:
#       Successfully uninstalled joblib-1.2.0
#   Attempting uninstall: executing
#     Found existing installation: executing 0.8.3
#     Uninstalling executing-0.8.3:
#       Successfully uninstalled executing-0.8.3
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: rich
#     Found existing installation: rich 13.3.5
#     Uninstalling rich-13.3.5:
#       Successfully uninstalled rich-13.3.5
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.4
#     Uninstalling pandas-2.1.4:
#       Successfully uninstalled pandas-2.1.4
#   Attempting uninstall: numba
#     Found existing installation: numba 0.59.0
#     Uninstalling numba-0.59.0:
#       Successfully uninstalled numba-0.59.0
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.8.0
#     Uninstalling matplotlib-3.8.0:
#       Successfully uninstalled matplotlib-3.8.0
#   Attempting uninstall: gensim
#     Found existing installation: gensim 4.3.0
#     Uninstalling gensim-4.3.0:
#       Successfully uninstalled gensim-4.3.0
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.14.0
#     Uninstalling statsmodels-0.14.0:
#       Successfully uninstalled statsmodels-0.14.0
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
#       Successfully uninstalled seaborn-0.12.2
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.12
#     Uninstalling pydantic-1.10.12:
#       Successfully uninstalled pydantic-1.10.12
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.19.2
#     Uninstalling jsonschema-4.19.2:
#       Successfully uninstalled jsonschema-4.19.2
#   Attempting uninstall: openai
#     Found existing installation: openai 1.34.0
#     Uninstalling openai-1.34.0:
#       Successfully uninstalled openai-1.34.0
# Successfully installed POT-0.9.4 aiofiles-24.1.0 aiolimiter-1.1.0 annotated-types-0.7.0 anytree-2.12.1 autograd-1.6.2 azure-common-1.1.28 azure-core-1.30.2 azure-identity-1.17.1 azure-search-documents-11.4.0 azure-storage-blob-12.20.0 beartype-0.18.5 cramjam-2.8.3 datashaper-0.0.49 deprecation-2.1.0 devtools-0.12.2 diskcache-5.6.3 environs-11.0.0 executing-2.0.1 fastparquet-2024.5.0 gensim-4.3.2 graphrag-0.1.1 graspologic-3.4.1 graspologic-native-1.2.1 hyppo-0.4.0 isodate-0.6.1 joblib-1.4.2 jsonschema-4.22.0 lancedb-0.9.0 llvmlite-0.43.0 matplotlib-3.9.1 msal-1.29.0 msal-extensions-1.2.0 numba-0.60.0 openai-1.35.10 pandas-2.2.2 patsy-0.5.6 portalocker-2.10.0 py-1.11.0 pyaml-env-1.2.1 pyarrow-15.0.0 pydantic-2.8.2 pydantic-core-2.20.1 pylance-0.13.0 pynndescent-0.5.13 python-dotenv-1.0.1 ratelimiter-1.2.0.post0 retry-0.9.2 rich-13.7.1 scikit-learn-1.5.1 scipy-1.12.0 seaborn-0.13.2 statsmodels-0.14.2 swifter-1.4.0 tenacity-8.4.2 textual-0.70.0 threadpoolctl-3.5.0 typing-extensions-4.12.2 umap-learn-0.5.6
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Administrator\AppData\Local\Temp\pip-uninstall-vl_s47qc'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\ProgramData\anaconda3\Lib\site-packages\~andas'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.15.0 requires gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1, which is not installed.
# streamlit 1.30.0 requires packaging<24,>=16.8, but you have packaging 24.1 which is incompatible.

# %%
import os

import pandas as pd
import tiktoken

from graphrag.query.indexer_adapters import read_indexer_entities, read_indexer_reports
from graphrag.query.llm.oai.chat_openai import ChatOpenAI
from graphrag.query.llm.oai.typing import OpenaiApiType
from graphrag.query.structured_search.global_search.community_context import (
    GlobalCommunityContext,
)
from graphrag.query.structured_search.global_search.search import GlobalSearch
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 6
#       3 import pandas as pd
#       4 import tiktoken
# ----> 6 from graphrag.query.indexer_adapters import read_indexer_entities, read_indexer_reports
#       7 from graphrag.query.llm.oai.chat_openai import ChatOpenAI
#       8 from graphrag.query.llm.oai.typing import OpenaiApiType
#
# File C:\ProgramData\anaconda3\Lib\site-packages\graphrag\query\indexer_adapters.py:14
#      11 import pandas as pd
#      13 from graphrag.model import CommunityReport, Covariate, Entity, Relationship, TextUnit
# ---> 14 from graphrag.query.input.loaders.dfs import (
#      15     read_community_reports,
#      16     read_covariates,
#      17     read_entities,
#      18     read_relationships,
#      19     read_text_units,
#      20 )
#      23 def read_indexer_text_units(final_text_units: pd.DataFrame) -> list[TextUnit]:
#      24     """Read in the Text Units from the raw indexing outputs."""
#
# File C:\ProgramData\anaconda3\Lib\site-packages\graphrag\query\input\loaders\dfs.py:26
#       8 from graphrag.model import (
#       9     Community,
#      10     CommunityReport,
#    (...)
#      15     TextUnit,
#      16 )
#      17 from graphrag.query.input.loaders.utils import (
#      18     to_list,
#      19     to_optional_dict,
#    (...)
#      24     to_str,
#      25 )
# ---> 26 from graphrag.vector_stores import BaseVectorStore, VectorStoreDocument
#      29 def read_entities(
#      30     df: pd.DataFrame,
#      31     id_col: str = "id",
#    (...)
#      43     attributes_cols: list[str] | None = None,
#      44 ) -> list[Entity]:
#      45     """Read entities from a dataframe."""
#
# File C:\ProgramData\anaconda3\Lib\site-packages\graphrag\vector_stores\__init__.py:8
#       6 from .azure_ai_search import AzureAISearch
#       7 from .base import BaseVectorStore, VectorStoreDocument, VectorStoreSearchResult
# ----> 8 from .lancedb import LanceDBVectorStore
#       9 from .typing import VectorStoreFactory, VectorStoreType
#      11 __all__ = [
#      12     "AzureAISearch",
#      13     "BaseVectorStore",
#    (...)
#      18     "VectorStoreType",
#      19 ]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\graphrag\vector_stores\lancedb.py:6
#       1 # Copyright (c) 2024 Microsoft Corporation.
#       2 # Licensed under the MIT License
#       4 """The LanceDB vector storage implementation package."""
# ----> 6 import lancedb as lancedb  # noqa: I001 (Ruff was breaking on this file imports, even tho they were sorted and passed local tests)
#       7 from graphrag.model.types import TextEmbedder
#       9 import json
#
# File C:\ProgramData\anaconda3\Lib\site-packages\lancedb\__init__.py:23
#      20 __version__ = importlib.metadata.version("lancedb")
#      22 from ._lancedb import connect as lancedb_connect
# ---> 23 from .common import URI, sanitize_uri
#      24 from .db import AsyncConnection, DBConnection, LanceDBConnection
#      25 from .remote.db import RemoteDBConnection
#
# File C:\ProgramData\anaconda3\Lib\site-packages\lancedb\common.py:19
#      16 import numpy as np
#      17 import pyarrow as pa
# ---> 19 from .util import safe_import_pandas
#      21 pd = safe_import_pandas()
#      23 DATA = Union[List[dict], dict, "pd.DataFrame", pa.Table, Iterable[pa.RecordBatch]]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\lancedb\util.py:26
#      24 import numpy as np
#      25 import pyarrow as pa
# ---> 26 import pyarrow.fs as pa_fs
#      28 from ._lancedb import validate_table_name as native_validate_table_name
#      31 def safe_import_adlfs():
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pyarrow\fs.py:24
#      18 """
#      19 FileSystem abstraction to interact with various local and remote filesystems.
#      20 """
#      22 from pyarrow.util import _is_path_like, _stringify_path
# ---> 24 from pyarrow._fs import (  # noqa
#      25     FileSelector,
#      26     FileType,
#      27     FileInfo,
#      28     FileSystem,
#      29     LocalFileSystem,
#      30     SubTreeFileSystem,
#      31     _MockFileSystem,
#      32     FileSystemHandler,
#      33     PyFileSystem,
#      34     _copy_files,
#      35     _copy_files_selector,
#      36 )
#      38 # For backward compatibility.
#      39 FileStats = FileInfo
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pyarrow\_fs.pyx:1, in init pyarrow._fs()
#
# ValueError: pyarrow.lib.NativeFile size changed, may indicate binary incompatibility. Expected 104 from C header, got 96 from PyObject

# %% [markdown]
# ## Global Search example
#
# Global search method generates answers by searching over all AI-generated community reports in a map-reduce fashion. This is a resource-intensive method, but often gives good responses for questions that require an understanding of the dataset as a whole (e.g. What are the most significant values of the herbs mentioned in this notebook?).

# %% [markdown]
# ### LLM setup

# %%
api_key = os.environ["GRAPHRAG_API_KEY"]
llm_model = os.environ["GRAPHRAG_LLM_MODEL"]

llm = ChatOpenAI(
    api_key=api_key,
    model=llm_model,
    api_type=OpenaiApiType.OpenAI,  # OpenaiApiType.OpenAI or OpenaiApiType.AzureOpenAI
    max_retries=20,
)

token_encoder = tiktoken.get_encoding("cl100k_base")

# %% [markdown]
# ### Load community reports as context for global search
#
# - Load all community reports in the `create_final_community_reports` table from the ire-indexing engine, to be used as context data for global search.
# - Load entities from the `create_final_nodes` and `create_final_entities` tables from the ire-indexing engine, to be used for calculating community weights for context ranking. Note that this is optional (if no entities are provided, we will not calculate community weights and only use the `rank` attribute in the community reports table for context ranking)

# %%
# parquet files generated from indexing pipeline
INPUT_DIR = "./inputs/operation dulce"
COMMUNITY_REPORT_TABLE = "create_final_community_reports"
ENTITY_TABLE = "create_final_nodes"
ENTITY_EMBEDDING_TABLE = "create_final_entities"

# community level in the Leiden community hierarchy from which we will load the community reports
# higher value means we use reports from more fine-grained communities (at the cost of higher computation cost)
COMMUNITY_LEVEL = 2

# %%
entity_df = pd.read_parquet(f"{INPUT_DIR}/{ENTITY_TABLE}.parquet")
report_df = pd.read_parquet(f"{INPUT_DIR}/{COMMUNITY_REPORT_TABLE}.parquet")
entity_embedding_df = pd.read_parquet(f"{INPUT_DIR}/{ENTITY_EMBEDDING_TABLE}.parquet")

reports = read_indexer_reports(report_df, entity_df, COMMUNITY_LEVEL)
entities = read_indexer_entities(entity_df, entity_embedding_df, COMMUNITY_LEVEL)
print(f"Report records: {len(report_df)}")
report_df.head()

# %% [markdown]
# #### Build global context based on community reports

# %%
context_builder = GlobalCommunityContext(
    community_reports=reports,
    entities=entities,  # default to None if you don't want to use community weights for ranking
    token_encoder=token_encoder,
)

# %% [markdown]
# #### Perform global search

# %%
context_builder_params = {
    "use_community_summary": False,  # False means using full community reports. True means using community short summaries.
    "shuffle_data": True,
    "include_community_rank": True,
    "min_community_rank": 0,
    "community_rank_name": "rank",
    "include_community_weight": True,
    "community_weight_name": "occurrence weight",
    "normalize_community_weight": True,
    "max_tokens": 12_000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 5000)
    "context_name": "Reports",
}

map_llm_params = {
    "max_tokens": 1000,
    "temperature": 0.0,
    "response_format": {"type": "json_object"},
}

reduce_llm_params = {
    "max_tokens": 2000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 1000-1500)
    "temperature": 0.0,
}

# %%
search_engine = GlobalSearch(
    llm=llm,
    context_builder=context_builder,
    token_encoder=token_encoder,
    max_data_tokens=12_000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 5000)
    map_llm_params=map_llm_params,
    reduce_llm_params=reduce_llm_params,
    allow_general_knowledge=False,  # set this to True will add instruction to encourage the LLM to incorporate general knowledge in the response, which may increase hallucinations, but could be useful in some use cases.
    json_mode=True,  # set this to False if your LLM model does not support JSON mode.
    context_builder_params=context_builder_params,
    concurrent_coroutines=32,
    response_type="multiple paragraphs",  # free form text describing the response type and format, can be anything, e.g. prioritized list, single paragraph, multiple paragraphs, multiple-page report
)

# %%
result = await search_engine.asearch(
    "What is the major conflict in this story and who are the protagonist and antagonist?"
)

print(result.response)

# %%
# inspect the data used to build the context for the LLM responses
result.context_data["reports"]

# %%
# inspect number of LLM calls and tokens
print(f"LLM calls: {result.llm_calls}. LLM tokens: {result.prompt_tokens}")
# Out:
# LLM calls: 13. LLM tokens: 184660
